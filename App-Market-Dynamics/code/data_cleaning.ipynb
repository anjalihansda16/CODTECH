# %%
import chardet
import pandas as pd

# %% [markdown]
# ## Fixing the file embedding

# %%
file_path_1 = "user_reviews.csv"

# %%
def detect_file_encoding(file_path_1):
    with open(file_path_1, 'rb') as f:
        raw_data = f.read()
        result = chardet.detect(raw_data)
        encoding = result['encoding']
        confidence = result['confidence']
        print(f"Detected Encoding: {encoding} (Confidence: {confidence * 100:.2f}%)")
        return encoding

# %%
detected_encoding = detect_file_encoding(file_path_1)
# Out:
# Detected Encoding: Windows-1254 (Confidence: 53.36%)

# %%
try_encodings = ['utf-8', 'latin1', 'cp1252', 'big5', 'gbk']

for encoding in try_encodings:
    try:
        with open(file_path_1, 'r', encoding=encoding) as f:
            data = f.read()
            print(f"Successfully decoded with {encoding}")
            break
    except UnicodeDecodeError as e:
        print(f"Failed with {encoding}: {e}")
# Out:
# Successfully decoded with utf-8

# %%
with open(file_path_1, 'rb') as f:
    raw_data = f.read()

decoded_data_1 = raw_data.decode('utf-8', errors='replace')

# %%
with open('fixed_file_1.txt', 'w', encoding='utf-8') as f:
    f.write(decoded_data_1)

# %%
user_review = pd.read_csv('fixed_file_1.txt')

# %%
file_path_2 = "apps.csv"

# %%
detected_encoding = detect_file_encoding(file_path_2)
# Out:
# Detected Encoding: Windows-1254 (Confidence: 51.48%)

# %%
try_encodings = ['utf-8', 'latin1', 'cp1252', 'big5', 'gbk']

for encoding in try_encodings:
    try:
        with open(file_path_2, 'r', encoding=encoding) as f:
            data = f.read()
            print(f"Successfully decoded with {encoding}")
            break
    except UnicodeDecodeError as e:
        print(f"Failed with {encoding}: {e}")
# Out:
# Successfully decoded with utf-8

# %%
with open(file_path_2, 'rb') as f:
    raw_data = f.read()

decoded_data_2 = raw_data.decode('utf-8', errors='replace')

# %%
with open('fixed_file_2.txt', 'w', encoding='utf-8') as f:
    f.write(decoded_data_2)

# %%
apps = pd.read_csv('fixed_file_2.txt')

# %% [markdown]
# ## Data Preparation

# %%
apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9659 entries, 0 to 9658
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   App              9659 non-null   object
#  1   Category_Proper  9659 non-null   object
#  2   Rating           8196 non-null   float64
#  3   Reviews          9659 non-null   int64
#  4   Size             8432 non-null   float64
#  5   Installs_num     9659 non-null   object
#  6   Installs         9659 non-null   object
#  7   Type             9659 non-null   object
#  8   Price ($)        9659 non-null   float64
#  9   Content Rating   9659 non-null   object
#  10  Sub-genre        393 non-null    object
#  11  Genre            9659 non-null   object
#  12  Last Updated     9659 non-null   object
#  13  Current Ver      9651 non-null   object
#  14  Android Ver      9657 non-null   object
#  15  Unnamed: 15      0 non-null      float64
#  16  Unnamed: 16      1 non-null      object
# dtypes: float64(4), int64(1), object(12)
# memory usage: 1.3+ MB

# %%
apps.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
apps.rename(columns={'Category_Proper': 'Category', 'Installs_num':'Installs (Num)'}, inplace=True)

# %%
user_review.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37427 entries, 0 to 37426
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   App                     37427 non-null  object
#  1   Translated_Review       37427 non-null  object
#  2   Sentiment               37427 non-null  object
#  3   Sentiment_Polarity      37427 non-null  float64
#  4   Sentiment_Subjectivity  37427 non-null  float64
# dtypes: float64(2), object(3)
# memory usage: 1.4+ MB

# %%
user_review.rename(columns={'Translated_Review':'Translated Review', 'Sentiment_Polarity':'Sentiment Polarity', 
                    'Sentiment_Subjectivity':'Sentiment Subjectivity'}, inplace=True)

# %% [markdown]
# ### Fixing App Names

# %%
from googletrans import Translator
from langdetect import detect, DetectorFactory
from langdetect.lang_detect_exception import LangDetectException

# %%
DetectorFactory.seed = 0

def get_non_english_app_names(df, column_name='App'):
    non_english_apps = []
    
    for app_name in df[column_name]:
        if pd.isnull(app_name):
            continue  
        try:
            if detect(app_name) != 'en':
                non_english_apps.append(app_name)
        except LangDetectException:
            print(f"Language detection failed for: {app_name}")
    
    return non_english_apps

# %%
translator = Translator()

# %%
def is_english(text):
    try:
        detected_lang = langdetect.detect(text)
        return detected_lang == 'en'
    except:
        return False

# %%
def translate_column(df, column_name, new_column_name):
    translations = []
    for text in df[column_name]:
        if is_english(text):
            translations.append(text)
        else:      
            try:
                translated_text = translator.translate(text, src='auto', dest='en').text
                translations.append(translated_text)
            except Exception as e:
                translations.append("Translation Error")  
    df[new_column_name] = pd.Series(translations)
    return df

# %% [markdown]
# ##### 1. user_review table

# %%
series = user_review['App'].unique()

# %%
user_review_app_name = pd.DataFrame(series, columns=['App'])

# %%
non_english_apps = get_non_english_app_names(user_review_app_name, column_name='App')

# %%
non_english_apps = pd.DataFrame(non_english_apps, columns=['App'])

# %%
non_english_apps
# Out:
#                                                    App
# 0                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 1                                                 11st
# 2    591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價...
# 3                                           591房屋交易-香港
# 4                                          8 Ball Pool
# ..                                                 ...
# 314                                   Homework Planner
# 315                                  Honkai Impact 3rd
# 316     Hostelworld: Hostels & Cheap Hotels Travel App
# 317                               Hot Wheels: Race Off
# 318                                            Hotstar
#
# [319 rows x 1 columns]

# %%
non_english_apps_translated = translate_column(non_english_apps, column_name='App', new_column_name='Translated App Name')

# %%
non_english_apps_translated
# Out:
#                                                    App  \
# 0                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 1                                                 11st
# 2    591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價...
# 3                                           591房屋交易-香港
# 4                                          8 Ball Pool
# ..                                                 ...
# 314                                   Homework Planner
# 315                                  Honkai Impact 3rd
# 316     Hostelworld: Hostels & Cheap Hotels Travel App
# 317                               Hot Wheels: Race Off
# 318                                            Hotstar
#
#                                    Translated App Name
# 0    104 Find a job -find a job to find a job to fi...
# 1                                                 11st
# 2    591 Housing Trading-Rental House, Middle Ages,...
# 3                          591 House Trading-Hong Kong
# 4                                          8 Ball Pool
# ..                                                 ...
# 314                                   Homework Planner
# 315                                  Honkai Impact 3rd
# 316     Hostelworld: Hostels & Cheap Hotels Travel App
# 317                               Hot Wheels: Race Off
# 318                                            Hotstar
#
# [319 rows x 2 columns]

# %% [markdown]
# ##### 2. apps table

# %%
series_2 = apps['App'].unique()

# %%
app_name = pd.DataFrame(series_2, columns=['App'])

# %%
app_name
# Out:
#                                                 App
# 0              "i DT" Fútbol. Todos Somos Técnicos.
# 1                                                .R
# 2                                            /u/app
# 3                                      [adult swim]
# 4                                        [BN] Blitz
# ...                                             ...
# 9654                      ZUL - Rotativo Digital BH
# 9655  zulily - Shop Daily Deals in Fashion and Home
# 9656               Zumper - Apartment Rental Finder
# 9657                     Zynga Poker – Texas Holdem
# 9658                                         #NAME?
#
# [9659 rows x 1 columns]

# %%
non_english_apps = get_non_english_app_names(app_name, column_name='App')
# Out:
# Language detection failed for: BQ-መጽሐፍ ቅዱሳዊ ጥያቄዎች
# Language detection failed for: DF@realtime
# Language detection failed for: Myjob@BM
# Language detection failed for: sustainability@BU

# %%
non_english_apps = pd.DataFrame(non_english_apps, columns=['App'])

# %%
non_english_apps
# Out:
#                                        App
# 0     "i DT" Fútbol. Todos Somos Técnicos.
# 1                                       .R
# 2                                   /u/app
# 3                             [adult swim]
# 4                               [BN] Blitz
# ...                                    ...
# 4349                              Zowi App
# 4350             ZUL - Rotativo Digital BH
# 4351      Zumper - Apartment Rental Finder
# 4352            Zynga Poker – Texas Holdem
# 4353                                #NAME?
#
# [4354 rows x 1 columns]

# %%
non_english_apps_translated_2 = translate_column(non_english_apps, column_name='App', new_column_name='Translated App Name')

# %%
non_english_apps_translated_2
# Out:
#                                        App  \
# 0     "i DT" Fútbol. Todos Somos Técnicos.
# 1                                       .R
# 2                                   /u/app
# 3                             [adult swim]
# 4                               [BN] Blitz
# ...                                    ...
# 4349                              Zowi App
# 4350             ZUL - Rotativo Digital BH
# 4351      Zumper - Apartment Rental Finder
# 4352            Zynga Poker – Texas Holdem
# 4353                                #NAME?
#
#                         Translated App Name
# 0     "I DT" Soccer.We are all technicians.
# 1                                        .R
# 2                                    /u/app
# 3                              [adult swim]
# 4                                [BN] Blitz
# ...                                     ...
# 4349                               Zowi APP
# 4350                Zul - BH Digital Rotary
# 4351       Zumper - Apartment Rental Finder
# 4352             Zynga Poker – Texas Holdem
# 4353                                 #NAME?
#
# [4354 rows x 2 columns]

# %% [markdown]
# ### Joining Translated App Name dfs with Main dfs

# %%
non_english_apps_translated
# Out:
#                                                    App  \
# 0                     104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 1                                                 11st
# 2    591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價...
# 3                                           591房屋交易-香港
# 4                                          8 Ball Pool
# ..                                                 ...
# 314                                   Homework Planner
# 315                                  Honkai Impact 3rd
# 316     Hostelworld: Hostels & Cheap Hotels Travel App
# 317                               Hot Wheels: Race Off
# 318                                            Hotstar
#
#                                    Translated App Name
# 0    104 Find a job -find a job to find a job to fi...
# 1                                                 11st
# 2    591 Housing Trading-Rental House, Middle Ages,...
# 3                          591 House Trading-Hong Kong
# 4                                          8 Ball Pool
# ..                                                 ...
# 314                                   Homework Planner
# 315                                  Honkai Impact 3rd
# 316     Hostelworld: Hostels & Cheap Hotels Travel App
# 317                               Hot Wheels: Race Off
# 318                                            Hotstar
#
# [319 rows x 2 columns]

# %%
final_user_review = pd.merge(user_review, non_english_apps_translated, how='left', on='App')

# %%
non_english_apps_translated_2
# Out:
#                                        App  \
# 0     "i DT" Fútbol. Todos Somos Técnicos.
# 1                                       .R
# 2                                   /u/app
# 3                             [adult swim]
# 4                               [BN] Blitz
# ...                                    ...
# 4349                              Zowi App
# 4350             ZUL - Rotativo Digital BH
# 4351      Zumper - Apartment Rental Finder
# 4352            Zynga Poker – Texas Holdem
# 4353                                #NAME?
#
#                         Translated App Name
# 0     "I DT" Soccer.We are all technicians.
# 1                                        .R
# 2                                    /u/app
# 3                              [adult swim]
# 4                                [BN] Blitz
# ...                                     ...
# 4349                               Zowi APP
# 4350                Zul - BH Digital Rotary
# 4351       Zumper - Apartment Rental Finder
# 4352             Zynga Poker – Texas Holdem
# 4353                                 #NAME?
#
# [4354 rows x 2 columns]

# %%
final_apps = pd.merge(apps, non_english_apps_translated_2, how='left', on='App')

# %%
final_apps
# Out:
#                                                 App           Category  \
# 0              "i DT" Fútbol. Todos Somos Técnicos.             Sports
# 1                                                .R              Tools
# 2                                            /u/app      Communication
# 3                                      [adult swim]             Family
# 4                                        [BN] Blitz             Sports
# ...                                             ...                ...
# 9654                      ZUL - Rotativo Digital BH  Auto and Vehicles
# 9655  zulily - Shop Daily Deals in Fashion and Home           Shopping
# 9656               Zumper - Apartment Rental Finder     House and Home
# 9657                     Zynga Poker – Texas Holdem               Game
# 9658                                         #NAME?             Comics
#
#       Rating  Reviews  Size Installs (Num)     Installs  Type  Price ($)  \
# 0        NaN       27   3.6            500         500+  Free        0.0
# 1        4.5      259   0.2         10,000      10,000+  Free        0.0
# 2        4.7      573  53.0         10,000      10,000+  Free        0.0
# 3        3.6    21433  21.0      10,00,000   1,000,000+  Free        0.0
# 4        3.2        4   5.6            100         100+  Free        0.0
# ...      ...      ...   ...            ...          ...   ...        ...
# 9654     4.2       29   NaN         10,000      10,000+  Free        0.0
# 9655     4.5    28560   NaN      10,00,000   1,000,000+  Free        0.0
# 9656     4.4    11200  25.0      10,00,000   1,000,000+  Free        0.0
# 9657     4.4  1986068  52.0    5,00,00,000  50,000,000+  Free        0.0
# 9658     3.5      115   9.1         10,000      10,000+  Free        0.0
#
#      Content Rating Sub-genre            Genre        Last Updated  \
# 0          Everyone       NaN           Sports     October 7, 2017
# 1          Everyone       NaN            Tools  September 16, 2014
# 2     Rated for 17+       NaN    Communication        July 3, 2018
# 3     Rated for 17+       NaN    Entertainment        May 29, 2018
# 4          Everyone       NaN           Sports        May 17, 2018
# ...             ...       ...              ...                 ...
# 9654       Everyone       NaN  Auto & Vehicles      August 1, 2018
# 9655       Everyone       NaN         Shopping       July 23, 2018
# 9656       Everyone       NaN     House & Home       July 16, 2018
# 9657  Rated for 13+       NaN           Casino       July 25, 2018
# 9658  Rated for 17+       NaN           Comics       July 13, 2018
#
#              Current Ver         Android Ver  \
# 0                   0.22          4.1 and up
# 1                 1.1.06          1.5 and up
# 2                  4.2.4          4.1 and up
# 3         3.0.1805181047          5.0 and up
# 4                    4.6          4.3 and up
# ...                  ...                 ...
# 9654               1.6.5          4.1 and up
# 9655  Varies with device  Varies with device
# 9656              4.5.15          5.0 and up
# 9657               21.54          4.1 and up
# 9658              5.0.12          5.0 and up
#
#                         Translated App Name
# 0     "I DT" Soccer.We are all technicians.
# 1                                        .R
# 2                                    /u/app
# 3                              [adult swim]
# 4                                [BN] Blitz
# ...                                     ...
# 9654                Zul - BH Digital Rotary
# 9655                                    NaN
# 9656       Zumper - Apartment Rental Finder
# 9657             Zynga Poker – Texas Holdem
# 9658                                 #NAME?
#
# [9659 rows x 16 columns]

# %% [markdown]
# ### Filling NA

# %%
final_apps['Translated App Name'] = final_apps['Translated App Name'].fillna(final_apps['App'])

# %%
final_apps
# Out:
#                                                 App           Category  \
# 0              "i DT" Fútbol. Todos Somos Técnicos.             Sports
# 1                                                .R              Tools
# 2                                            /u/app      Communication
# 3                                      [adult swim]             Family
# 4                                        [BN] Blitz             Sports
# ...                                             ...                ...
# 9654                      ZUL - Rotativo Digital BH  Auto and Vehicles
# 9655  zulily - Shop Daily Deals in Fashion and Home           Shopping
# 9656               Zumper - Apartment Rental Finder     House and Home
# 9657                     Zynga Poker – Texas Holdem               Game
# 9658                                         #NAME?             Comics
#
#       Rating  Reviews  Size Installs (Num)     Installs  Type  Price ($)  \
# 0        NaN       27   3.6            500         500+  Free        0.0
# 1        4.5      259   0.2         10,000      10,000+  Free        0.0
# 2        4.7      573  53.0         10,000      10,000+  Free        0.0
# 3        3.6    21433  21.0      10,00,000   1,000,000+  Free        0.0
# 4        3.2        4   5.6            100         100+  Free        0.0
# ...      ...      ...   ...            ...          ...   ...        ...
# 9654     4.2       29   NaN         10,000      10,000+  Free        0.0
# 9655     4.5    28560   NaN      10,00,000   1,000,000+  Free        0.0
# 9656     4.4    11200  25.0      10,00,000   1,000,000+  Free        0.0
# 9657     4.4  1986068  52.0    5,00,00,000  50,000,000+  Free        0.0
# 9658     3.5      115   9.1         10,000      10,000+  Free        0.0
#
#      Content Rating Sub-genre            Genre        Last Updated  \
# 0          Everyone       NaN           Sports     October 7, 2017
# 1          Everyone       NaN            Tools  September 16, 2014
# 2     Rated for 17+       NaN    Communication        July 3, 2018
# 3     Rated for 17+       NaN    Entertainment        May 29, 2018
# 4          Everyone       NaN           Sports        May 17, 2018
# ...             ...       ...              ...                 ...
# 9654       Everyone       NaN  Auto & Vehicles      August 1, 2018
# 9655       Everyone       NaN         Shopping       July 23, 2018
# 9656       Everyone       NaN     House & Home       July 16, 2018
# 9657  Rated for 13+       NaN           Casino       July 25, 2018
# 9658  Rated for 17+       NaN           Comics       July 13, 2018
#
#              Current Ver         Android Ver  \
# 0                   0.22          4.1 and up
# 1                 1.1.06          1.5 and up
# 2                  4.2.4          4.1 and up
# 3         3.0.1805181047          5.0 and up
# 4                    4.6          4.3 and up
# ...                  ...                 ...
# 9654               1.6.5          4.1 and up
# 9655  Varies with device  Varies with device
# 9656              4.5.15          5.0 and up
# 9657               21.54          4.1 and up
# 9658              5.0.12          5.0 and up
#
#                                 Translated App Name
# 0             "I DT" Soccer.We are all technicians.
# 1                                                .R
# 2                                            /u/app
# 3                                      [adult swim]
# 4                                        [BN] Blitz
# ...                                             ...
# 9654                        Zul - BH Digital Rotary
# 9655  zulily - Shop Daily Deals in Fashion and Home
# 9656               Zumper - Apartment Rental Finder
# 9657                     Zynga Poker – Texas Holdem
# 9658                                         #NAME?
#
# [9659 rows x 16 columns]

# %%
final_user_review['Translated App Name'] = final_user_review['Translated App Name'].fillna(final_user_review['App'])

# %%
final_user_review
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 37422  Housing-Real Estate & Property
# 37423  Housing-Real Estate & Property
# 37424  Housing-Real Estate & Property
# 37425  Housing-Real Estate & Property
# 37426  Housing-Real Estate & Property
#
#                                        Translated Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2             Works great especially going grocery store  Positive
# 3                                           Best idea us  Positive
# 4                                               Best way  Positive
# ...                                                  ...       ...
# 37422  Most ads older many agents ..not much owner po...  Positive
# 37423  If photos posted portal load, fit purpose. I'm...  Positive
# 37424  Dumb app, I wanted post property rent give opt...  Negative
# 37425  I property business got link SMS happy perform...  Positive
# 37426  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment Polarity  Sentiment Subjectivity  \
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 37422            0.173333                0.486667
# 37423            0.225000                0.447222
# 37424           -0.287500                0.250000
# 37425            0.800000                1.000000
# 37426           -0.316667                0.400000
#
#                   Translated App Name
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 37422  Housing-Real Estate & Property
# 37423  Housing-Real Estate & Property
# 37424  Housing-Real Estate & Property
# 37425  Housing-Real Estate & Property
# 37426  Housing-Real Estate & Property
#
# [37427 rows x 6 columns]

# %% [markdown]
# ### Creating Unique IDs for Apps

# %%
final_apps['Unique ID'] = pd.factorize(final_apps['App'])[0]

# %%
final_apps = final_apps [['Unique ID', 'App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs (Num)', 'Installs', 'Type', 'Price ($)', 
                        'Content Rating', 'Sub-genre', 'Genre', 'Last Updated', 'Current Ver', 'Android Ver', 'Translated App Name']]

# %%
final_apps
# Out:
#       Unique ID                                            App  \
# 0             0           "i DT" Fútbol. Todos Somos Técnicos.
# 1             1                                             .R
# 2             2                                         /u/app
# 3             3                                   [adult swim]
# 4             4                                     [BN] Blitz
# ...         ...                                            ...
# 9654       9654                      ZUL - Rotativo Digital BH
# 9655       9655  zulily - Shop Daily Deals in Fashion and Home
# 9656       9656               Zumper - Apartment Rental Finder
# 9657       9657                     Zynga Poker – Texas Holdem
# 9658       9658                                         #NAME?
#
#                Category  Rating  Reviews  Size Installs (Num)     Installs  \
# 0                Sports     NaN       27   3.6            500         500+
# 1                 Tools     4.5      259   0.2         10,000      10,000+
# 2         Communication     4.7      573  53.0         10,000      10,000+
# 3                Family     3.6    21433  21.0      10,00,000   1,000,000+
# 4                Sports     3.2        4   5.6            100         100+
# ...                 ...     ...      ...   ...            ...          ...
# 9654  Auto and Vehicles     4.2       29   NaN         10,000      10,000+
# 9655           Shopping     4.5    28560   NaN      10,00,000   1,000,000+
# 9656     House and Home     4.4    11200  25.0      10,00,000   1,000,000+
# 9657               Game     4.4  1986068  52.0    5,00,00,000  50,000,000+
# 9658             Comics     3.5      115   9.1         10,000      10,000+
#
#       Type  Price ($) Content Rating Sub-genre            Genre  \
# 0     Free        0.0       Everyone       NaN           Sports
# 1     Free        0.0       Everyone       NaN            Tools
# 2     Free        0.0  Rated for 17+       NaN    Communication
# 3     Free        0.0  Rated for 17+       NaN    Entertainment
# 4     Free        0.0       Everyone       NaN           Sports
# ...    ...        ...            ...       ...              ...
# 9654  Free        0.0       Everyone       NaN  Auto & Vehicles
# 9655  Free        0.0       Everyone       NaN         Shopping
# 9656  Free        0.0       Everyone       NaN     House & Home
# 9657  Free        0.0  Rated for 13+       NaN           Casino
# 9658  Free        0.0  Rated for 17+       NaN           Comics
#
#             Last Updated         Current Ver         Android Ver  \
# 0        October 7, 2017                0.22          4.1 and up
# 1     September 16, 2014              1.1.06          1.5 and up
# 2           July 3, 2018               4.2.4          4.1 and up
# 3           May 29, 2018      3.0.1805181047          5.0 and up
# 4           May 17, 2018                 4.6          4.3 and up
# ...                  ...                 ...                 ...
# 9654      August 1, 2018               1.6.5          4.1 and up
# 9655       July 23, 2018  Varies with device  Varies with device
# 9656       July 16, 2018              4.5.15          5.0 and up
# 9657       July 25, 2018               21.54          4.1 and up
# 9658       July 13, 2018              5.0.12          5.0 and up
#
#                                 Translated App Name
# 0             "I DT" Soccer.We are all technicians.
# 1                                                .R
# 2                                            /u/app
# 3                                      [adult swim]
# 4                                        [BN] Blitz
# ...                                             ...
# 9654                        Zul - BH Digital Rotary
# 9655  zulily - Shop Daily Deals in Fashion and Home
# 9656               Zumper - Apartment Rental Finder
# 9657                     Zynga Poker – Texas Holdem
# 9658                                         #NAME?
#
# [9659 rows x 17 columns]

# %% [markdown]
# #### Storing data for further processing

# %%
final_user_review
# Out:
#                                   App  \
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 53934  Housing-Real Estate & Property
# 53935  Housing-Real Estate & Property
# 53936  Housing-Real Estate & Property
# 53937  Housing-Real Estate & Property
# 53938  Housing-Real Estate & Property
#
#                                        Translated Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2             Works great especially going grocery store  Positive
# 3                                           Best idea us  Positive
# 4                                               Best way  Positive
# ...                                                  ...       ...
# 53934  Most ads older many agents ..not much owner po...  Positive
# 53935  If photos posted portal load, fit purpose. I'm...  Positive
# 53936  Dumb app, I wanted post property rent give opt...  Negative
# 53937  I property business got link SMS happy perform...  Positive
# 53938  Useless app, I searched flats kondapur, Hydera...  Negative
#
#        Sentiment Polarity  Sentiment Subjectivity  \
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 53934            0.173333                0.486667
# 53935            0.225000                0.447222
# 53936           -0.287500                0.250000
# 53937            0.800000                1.000000
# 53938           -0.316667                0.400000
#
#                   Translated App Name
# 0               10 Best Foods for You
# 1               10 Best Foods for You
# 2               10 Best Foods for You
# 3               10 Best Foods for You
# 4               10 Best Foods for You
# ...                               ...
# 53934  Housing-Real Estate & Property
# 53935  Housing-Real Estate & Property
# 53936  Housing-Real Estate & Property
# 53937  Housing-Real Estate & Property
# 53938  Housing-Real Estate & Property
#
# [53939 rows x 6 columns]

# %%
final_user_review.to_csv('final_user_review.csv', index=False, encoding='utf-8')

# %%
final_apps.to_csv('final_apps.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Final Merge

# %%
user_review = pd.read_csv('final_user_review.csv')

# %%
apps = pd.read_csv('final_apps.csv')

# %%
result = pd.merge(user_review, apps[['Unique ID', 'Translated App Name']], how='left', on='Translated App Name')

# %%
result.drop_duplicates(inplace=True)

# %%
unmatched_list = result[result['Unique ID'].isnull()]['App'].unique()

# %%
len(unmatched_list)
# Out:
# 47

# %%
unmatched_list
# Out:
# array(['104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室',
#        '591房屋交易-租屋、中古屋、新建案、實價登錄、別墅透天、公寓套房、捷運、買房賣房行情、房價房貸查詢', '591房屋交易-香港',
#        'ANA', 'AirBrush: Easy Photo Editor', 'Apple Daily 蘋果動新聞',
#        'Aprender inglés con Wlingua', 'BaBe - Baca Berita',
#        'BaBe Lite - Baca Berita Hemat Kuota', 'BaBe+ - Berita Indonesia',
#        'Bagan - Myanmar Keyboard', 'Banco Itaú', 'Banco do Brasil',
#        'Bangla Newspaper – Prothom Alo', 'Banque Populaire',
#        'Birdays – Birthday reminder',
#        'Brasileirão Pro 2018 - Série A e B', 'Buienradar - weer',
#        'Bukalapak - Jual Beli Online', 'BukuBayi - Perkembangan Bayi',
#        'Buscapé - Ofertas e descontos', 'BÁO MỚI - Đọc Báo, Tin Tức 24h',
#        'CAIXA', 'Caf - Mon Compte', 'Claro',
#        'ColorFil - Adult Coloring Book', 'Curso de Ingles Gratis',
#        'Cut the Rope 2', 'DELISH KITCHEN - 無料レシピ動画で料理を楽しく・簡単に！',
#        'Daum Mail - 다음 메일',
#        'Delivery Club–Доставка еды:пицца,суши,бургер,салат',
#        'Despegar.com Hoteles y Vuelos', 'Detector de Radares Gratis',
#        'Die TK-App – alles im Griff', 'Dil Mil', 'Divar',
#        'Domofond Недвижимость. Купить, снять квартиру.',
#        'Dr. Oetker Rezeptideen', 'Draw Your Game',
#        'Draw a Stickman: EPIC 2', 'Easy - taxi, car, ridesharing',
#        'El tiempo de AEMET', 'Enterprise Rent-A-Car',
#        'Facetune - Ad Free',
#        'Foot Mercato : transferts, résultats, news, live',
#        'GANMA! - オリジナル漫画が全話無料で読み放題', 'Home Street – Home Design Game'],
#       dtype=object)

# %%
incomplete_user_review_df = result[result['Unique ID'].isnull()]

# %%
result = result.dropna(subset=['Unique ID'])

# %%
result['Unique ID'] = result['Unique ID'].astype(int)

# %%
incomplete_user_review_df.drop('Unique ID', axis=1, inplace=True)

# %%
incomplete_user_review_df.reset_index()
# Out:
#         index                               App  \
# 0         194  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 1         195  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2         196  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 3         197  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 4         198  104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# ...       ...                               ...
# 1365  1654702    Home Street – Home Design Game
# 1366  1654703    Home Street – Home Design Game
# 1367  1654704    Home Street – Home Design Game
# 1368  1654705    Home Street – Home Design Game
# 1369  1654706    Home Street – Home Design Game
#
#                                       Translated Review Sentiment  \
# 0                                                 Great  Positive
# 1                                                  nice  Positive
# 2                                   Almost mobile phone   Neutral
# 3     Very effective, efficient convenient find avai...  Positive
# 4                                        Easy intuitive  Positive
# ...                                                 ...       ...
# 1365                                  There many things  Positive
# 1366  This game fun also little boring okay game u w...  Negative
# 1367  It nice I would recommend would work without n...  Positive
# 1368                              I anything say I love  Positive
# 1369                            Good graphics, fun play  Positive
#
#       Sentiment Polarity  Sentiment Subjectivity  \
# 0               0.800000                0.750000
# 1               0.600000                1.000000
# 2               0.000000                0.000000
# 3               0.626667                0.666667
# 4               0.433333                0.833333
# ...                  ...                     ...
# 1365            0.500000                0.500000
# 1366           -0.197917                0.500000
# 1367            0.311111                0.555556
# 1368            0.500000                0.600000
# 1369            0.500000                0.400000
#
#                                     Translated App Name
# 0     104 Find a job -find a job to find a job to fi...
# 1     104 Find a job -find a job to find a job to fi...
# 2     104 Find a job -find a job to find a job to fi...
# 3     104 Find a job -find a job to find a job to fi...
# 4     104 Find a job -find a job to find a job to fi...
# ...                                                 ...
# 1365                     Home Street – Home Design Game
# 1366                     Home Street – Home Design Game
# 1367                     Home Street – Home Design Game
# 1368                     Home Street – Home Design Game
# 1369                     Home Street – Home Design Game
#
# [1370 rows x 7 columns]

# %%
incomplete_user_review_df
# Out:
#                                       App  \
# 194      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 195      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 196      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 197      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 198      104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# ...                                   ...
# 1654702    Home Street – Home Design Game
# 1654703    Home Street – Home Design Game
# 1654704    Home Street – Home Design Game
# 1654705    Home Street – Home Design Game
# 1654706    Home Street – Home Design Game
#
#                                          Translated Review Sentiment  \
# 194                                                  Great  Positive
# 195                                                   nice  Positive
# 196                                    Almost mobile phone   Neutral
# 197      Very effective, efficient convenient find avai...  Positive
# 198                                         Easy intuitive  Positive
# ...                                                    ...       ...
# 1654702                                  There many things  Positive
# 1654703  This game fun also little boring okay game u w...  Negative
# 1654704  It nice I would recommend would work without n...  Positive
# 1654705                              I anything say I love  Positive
# 1654706                            Good graphics, fun play  Positive
#
#          Sentiment Polarity  Sentiment Subjectivity  \
# 194                0.800000                0.750000
# 195                0.600000                1.000000
# 196                0.000000                0.000000
# 197                0.626667                0.666667
# 198                0.433333                0.833333
# ...                     ...                     ...
# 1654702            0.500000                0.500000
# 1654703           -0.197917                0.500000
# 1654704            0.311111                0.555556
# 1654705            0.500000                0.600000
# 1654706            0.500000                0.400000
#
#                                        Translated App Name
# 194      104 Find a job -find a job to find a job to fi...
# 195      104 Find a job -find a job to find a job to fi...
# 196      104 Find a job -find a job to find a job to fi...
# 197      104 Find a job -find a job to find a job to fi...
# 198      104 Find a job -find a job to find a job to fi...
# ...                                                    ...
# 1654702                     Home Street – Home Design Game
# 1654703                     Home Street – Home Design Game
# 1654704                     Home Street – Home Design Game
# 1654705                     Home Street – Home Design Game
# 1654706                     Home Street – Home Design Game
#
# [1370 rows x 6 columns]

# %%
incomplete_user_review_df.to_csv('incomplete_user_review.csv', index=False, encoding='utf-8')

# %%
apps_subset = apps[['Unique ID', 'App', 'Translated App Name']]

# %%
apps_subset
# Out:
#       Unique ID                                            App  \
# 0             0           "i DT" Fútbol. Todos Somos Técnicos.
# 1             1                                             .R
# 2             2                                         /u/app
# 3             3                                   [adult swim]
# 4             4                                     [BN] Blitz
# ...         ...                                            ...
# 9654       9654                      ZUL - Rotativo Digital BH
# 9655       9655  zulily - Shop Daily Deals in Fashion and Home
# 9656       9656               Zumper - Apartment Rental Finder
# 9657       9657                     Zynga Poker – Texas Holdem
# 9658       9658                                         #NAME?
#
#                                 Translated App Name
# 0             "I DT" Soccer.We are all technicians.
# 1                                                .R
# 2                                            /u/app
# 3                                      [adult swim]
# 4                                        [BN] Blitz
# ...                                             ...
# 9654                        Zul - BH Digital Rotary
# 9655  zulily - Shop Daily Deals in Fashion and Home
# 9656               Zumper - Apartment Rental Finder
# 9657                     Zynga Poker – Texas Holdem
# 9658                                         #NAME?
#
# [9659 rows x 3 columns]

# %%
apps_subset.to_csv('apps_subset.csv', index=False, encoding='utf-8')

# %% [markdown]
# ## Dataset for Fuzzy Match in Power Query

# %%
sheet_name = "result_2"

# %%
result_2 = pd.read_excel("final.xlsx", sheet_name=sheet_name)

# %%
result_2.rename(columns={'apps_subset.Unique ID':'Unique ID'}, inplace=True)

# %%
result_2
# Out:
#                                   App  \
# 0    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 1    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 2    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 3    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# 4    104 找工作 - 找工作 找打工 找兼職 履歷健檢 履歷診療室
# ..                                ...
# 855            Dr. Oetker Rezeptideen
# 856            Dr. Oetker Rezeptideen
# 857            Dr. Oetker Rezeptideen
# 858            Dr. Oetker Rezeptideen
# 859            Dr. Oetker Rezeptideen
#
#                                      Translated Review Sentiment  \
# 0                                                Great  Positive
# 1                                                 nice  Positive
# 2                                  Almost mobile phone   Neutral
# 3    Very effective, efficient convenient find avai...  Positive
# 4                                       Easy intuitive  Positive
# ..                                                 ...       ...
# 855                             Nice It nice great Ui.  Positive
# 856   Can I translate language english Give reply soon   Neutral
# 857                         nice design good work guys  Positive
# 858                             Easy recipes easy bake  Positive
# 859                english Please give english version   Neutral
#
#      Sentiment Polarity  Sentiment Subjectivity  \
# 0              0.800000                0.750000
# 1              0.600000                1.000000
# 2              0.000000                0.000000
# 3              0.626667                0.666667
# 4              0.433333                0.833333
# ..                  ...                     ...
# 855            0.666667                0.916667
# 856            0.000000                0.000000
# 857            0.650000                0.800000
# 858            0.433333                0.833333
# 859            0.000000                0.000000
#
#                                    Translated App Name  Unique ID
# 0    104 Find a job -find a job to find a job to fi...         24
# 1    104 Find a job -find a job to find a job to fi...         24
# 2    104 Find a job -find a job to find a job to fi...         24
# 3    104 Find a job -find a job to find a job to fi...         24
# 4    104 Find a job -find a job to find a job to fi...         24
# ..                                                 ...        ...
# 855                             Dr.Oetker recipe ideas       3376
# 856                             Dr.Oetker recipe ideas       3376
# 857                             Dr.Oetker recipe ideas       3376
# 858                             Dr.Oetker recipe ideas       3376
# 859                             Dr.Oetker recipe ideas       3376
#
# [860 rows x 7 columns]

# %%
result
# Out:
#                                     App  \
# 0                 10 Best Foods for You
# 1                 10 Best Foods for You
# 2                 10 Best Foods for You
# 3                 10 Best Foods for You
# 4                 10 Best Foods for You
# ...                                 ...
# 1655598  Housing-Real Estate & Property
# 1655599  Housing-Real Estate & Property
# 1655600  Housing-Real Estate & Property
# 1655601  Housing-Real Estate & Property
# 1655602  Housing-Real Estate & Property
#
#                                          Translated Review Sentiment  \
# 0        I like eat delicious food. That's I'm cooking ...  Positive
# 1          This help eating healthy exercise regular basis  Positive
# 2               Works great especially going grocery store  Positive
# 3                                             Best idea us  Positive
# 4                                                 Best way  Positive
# ...                                                    ...       ...
# 1655598  Most ads older many agents ..not much owner po...  Positive
# 1655599  If photos posted portal load, fit purpose. I'm...  Positive
# 1655600  Dumb app, I wanted post property rent give opt...  Negative
# 1655601  I property business got link SMS happy perform...  Positive
# 1655602  Useless app, I searched flats kondapur, Hydera...  Negative
#
#          Sentiment Polarity  Sentiment Subjectivity  \
# 0                  1.000000                0.533333
# 1                  0.250000                0.288462
# 2                  0.400000                0.875000
# 3                  1.000000                0.300000
# 4                  1.000000                0.300000
# ...                     ...                     ...
# 1655598            0.173333                0.486667
# 1655599            0.225000                0.447222
# 1655600           -0.287500                0.250000
# 1655601            0.800000                1.000000
# 1655602           -0.316667                0.400000
#
#                     Translated App Name  Unique ID
# 0                 10 Best Foods for You         16
# 1                 10 Best Foods for You         16
# 2                 10 Best Foods for You         16
# 3                 10 Best Foods for You         16
# 4                 10 Best Foods for You         16
# ...                                 ...        ...
# 1655598  Housing-Real Estate & Property       5420
# 1655599  Housing-Real Estate & Property       5420
# 1655600  Housing-Real Estate & Property       5420
# 1655601  Housing-Real Estate & Property       5420
# 1655602  Housing-Real Estate & Property       5420
#
# [40802 rows x 7 columns]

# %%
df = pd.concat([result, result_2], ignore_index=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df = df[['Unique ID', 'App', 'Translated Review', 'Sentiment', 'Sentiment Polarity', 'Sentiment Subjectivity']]

# %%
df
# Out:
#        Unique ID                     App  \
# 0             16   10 Best Foods for You
# 1             16   10 Best Foods for You
# 2             16   10 Best Foods for You
# 3             16   10 Best Foods for You
# 4             16   10 Best Foods for You
# ...          ...                     ...
# 41657       3376  Dr. Oetker Rezeptideen
# 41658       3376  Dr. Oetker Rezeptideen
# 41659       3376  Dr. Oetker Rezeptideen
# 41660       3376  Dr. Oetker Rezeptideen
# 41661       3376  Dr. Oetker Rezeptideen
#
#                                        Translated Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2             Works great especially going grocery store  Positive
# 3                                           Best idea us  Positive
# 4                                               Best way  Positive
# ...                                                  ...       ...
# 41657                             Nice It nice great Ui.  Positive
# 41658   Can I translate language english Give reply soon   Neutral
# 41659                         nice design good work guys  Positive
# 41660                             Easy recipes easy bake  Positive
# 41661                english Please give english version   Neutral
#
#        Sentiment Polarity  Sentiment Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.400000                0.875000
# 3                1.000000                0.300000
# 4                1.000000                0.300000
# ...                   ...                     ...
# 41657            0.666667                0.916667
# 41658            0.000000                0.000000
# 41659            0.650000                0.800000
# 41660            0.433333                0.833333
# 41661            0.000000                0.000000
#
# [41662 rows x 6 columns]

# %%
df.to_csv('user_review_final_df.csv', index=False, encoding='utf-8')

# %%
apps.drop('Translated App Name', axis=1, inplace=True)

# %%
apps.to_csv('apps_final_df.csv', index=False, encoding='utf-8')
